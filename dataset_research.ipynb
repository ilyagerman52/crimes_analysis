# %%
# !wget https://github.com/ilyagerman52/crimes_analysis/raw/main/crimedata.csv%20.zip
# Out:
# --2022-12-07 19:11:07--  https://github.com/ilyagerman52/crimes_analysis/raw/main/crimedata.csv%20(1).zip
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/ilyagerman52/crimes_analysis/main/crimedata.csv%20(1).zip [following]
# --2022-12-07 19:11:08--  https://raw.githubusercontent.com/ilyagerman52/crimes_analysis/main/crimedata.csv%20(1).zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 661307 (646K) [application/zip]
# Saving to: ‘crimedata.csv (1).zip’
#
# crimedata.csv (1).z 100%[===================>] 645.81K  --.-KB/s    in 0.006s
#
# ...

# %%
# !unzip crimedata.csv.zip
# Out:
# Archive:  crimedata.csv.zip
#   inflating: crimedata.csv

# %%
import pandas as pd

# %%
data = pd.read_csv('crimedata.csv')

# %%
data.sample(3)
# Out:
#                    communityName state  countyCode  communityCode  population  \
# 1349      NorthRichlandHillscity    TX         NaN            NaN       45895
# 781              HarperWoodscity    MI       163.0        36700.0       14903
# 188   SouthOrangeVillagetownship    NJ        13.0        69274.0       16390
#
#       householdsize  racepctblack  racePctWhite  racePctAsian  racePctHisp  \
# 1349           2.72          1.81         93.64          1.64         5.84
# 781            2.27          0.89         97.86          0.90         1.02
# 188            3.17         18.69         76.63          3.42         3.27
#
#       ...  burglaries  burglPerPop  larcenies  larcPerPop  autoTheft  \
# 1349  ...       389.0       688.31     1669.0     2953.20      229.0
# 781   ...        78.0       543.86     1748.0    12187.98      240.0
# 188   ...       224.0      1344.70      498.0     2989.55      496.0
#
#       autoTheftPerPop  arsons  arsonsPerPop  ViolentCrimesPerPop  \
# ...

# %%
print(*list(data.columns), sep='\n')
# Out:
# communityName
# state
# countyCode
# communityCode
# population
# householdsize
# racepctblack
# racePctWhite
# racePctAsian
# racePctHisp
# agePct12t21
# agePct12t29
# agePct16t24
# agePct65up
# numbUrban
# pctUrban
# medIncome
# pctWWage
# pctWFarmSelf
# pctWInvInc
# pctWSocSec
# pctWPubAsst
# pctWRetire
# medFamInc
# perCapInc
# whitePerCap
# blackPerCap
# indianPerCap
# AsianPerCap
# OtherPerCap
# HispPerCap
# NumUnderPov
# PctPopUnderPov
# PctLess9thGrade
# PctNotHSGrad
# PctBSorMore
# PctUnemployed
# PctEmploy
# PctEmplManu
# PctEmplProfServ
# PctOccupManu
# PctOccupMgmtProf
# MalePctDivorce
# MalePctNevMarr
# FemalePctDiv
# TotalPctDiv
# PersPerFam
# PctFam2Par
# PctKids2Par
# PctYoungKids2Par
# PctTeen2Par
# PctWorkMomYoungKids
# PctWorkMom
# NumKidsBornNeverMar
# PctKidsBornNeverMar
# NumImmig
# PctImmigRecent
# PctImmigRec5
# PctImmigRec8
# PctImmigRec10
# PctRecentImmig
# PctRecImmig5
# PctRecImmig8
# PctRecImmig10
# PctSpeakEnglOnly
# PctNotSpeakEnglWell
# ...
